# %% [markdown]
# ## Observations and Insights

# %%
print(f"1. The drugs Capomulin and Ramicane had the highest number of mice out all the regimens. But the study overall had a near \n equal number of female to male mice. This may account for gender differecnes of reaction.")
print(f"2. Regimens for Capomulin and Ramicane appear to have a less of a flucation of tumor size than Infubinol and Ceftamin. These two regimens could produce a larger success for decreasing Tumor size. Capomulin and Ceftamin appear to have a large \n variation between them.")
print(f"3. Regimen for Capomulin demonstrated great success of shrinking the tumor size in subkject x401. This helps demonstrate \n that Capomulin may be a viable product for the public. Further study would have to be performed, as shown by the regression model. Further analysis would need to test the relationship between mouse size, tumor volume, tumor shrinkage. As the \n regression analysis shows larger mice have larger tumors.")
# Out:
# 1. The drugs Capomulin and Ramicane had the highest number of mice out all the regimens. But the study overall had a near
#  equal number of female to male mice. This may account for gender differecnes of reaction.
# 2. Regimens for Capomulin and Ramicane appear to have a less of a flucation of tumor size than Infubinol and Ceftamin. These two regimens could produce a larger success for decreasing Tumor size. Capomulin and Ceftamin appear to have a large
#  variation between them.
# 3. Regimen for Capomulin demonstrated great success of shrinking the tumor size in subkject x401. This helps demonstrate
#  that Capomulin may be a viable product for the public. Further study would have to be performed, as shown by the regression model. Further analysis would need to test the relationship between mouse size, tumor volume, tumor shrinkage. As the
#  regression analysis shows larger mice have larger tumors.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import random 
from scipy.stats import sem 
from scipy.stats import linregress
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
Mouse_study_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer" )
# Display the data table for preview
Mouse_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
Mouse_count_df = Mouse_study_df["Mouse ID"].count()
print(Mouse_count_df)
Mouse_unique_count_df = Mouse_study_df["Mouse ID"].nunique()
print(Mouse_unique_count_df)
# Out:
# 1893
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#df.loc[df['shield'] > 6, ['max_speed']]
Mouse_duplicates_timepoint_df = Mouse_study_df.loc[Mouse_study_df.duplicated(subset=["Mouse ID","Timepoint"]), ["Mouse ID"]]
Mouse_duplicates_timepoint_df
# Out:
#     Mouse ID
# 909     g989
# 911     g989
# 913     g989
# 915     g989
# 917     g989

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
##I verified on my resulting datafram that there were no more duplicates, by re-running the code used above to find duplicates. There were no more duplicates for mouse ID and Timepoint.
Mouse_study_cleaned_df = Mouse_study_df.drop_duplicates(subset=["Mouse ID", "Timepoint"], keep="first")
Mouse_study_cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(Mouse_study_cleaned_df["Mouse ID"].count())
print(Mouse_study_cleaned_df["Mouse ID"].nunique())
# Out:
# 1888
# 249

# %%
(Mouse_study_cleaned_df["Drug Regimen"].nunique())
(Mouse_study_cleaned_df["Drug Regimen"].value_counts())
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

Mouse_study_grouped_drug_tumor_df = Mouse_study_cleaned_df.groupby("Drug Regimen")["Tumor Volume (mm3)"]

Mouse_study_mean_df= Mouse_study_grouped_drug_tumor_df.mean()

Mouse_study_median_df = Mouse_study_grouped_drug_tumor_df.median()

Mouse_study_variance = Mouse_study_grouped_drug_tumor_df.var()

Mouse_study_standard_deviation_df = Mouse_study_grouped_drug_tumor_df.std()

Mouse_study_SEM_df = Mouse_study_grouped_drug_tumor_df.sem()

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
Mouse_study_summary_df = pd.DataFrame({"Mean": Mouse_study_mean_df, "Median": Mouse_study_median_df, "Variance": Mouse_study_variance, "Standard Deviation": Mouse_study_standard_deviation_df, "SEM": Mouse_study_SEM_df})
Mouse_study_summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
Mouse_study_summary_df
# Using the aggregation method, produce the same summary statistics in a single line
Mouse_study_summary_2_df=Mouse_study_cleaned_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]})
Mouse_study_summary_2_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
plt.figure(figsize=(15,5))
Mouse_study_count = Mouse_study_cleaned_df.groupby("Drug Regimen")["Mouse ID"].count()
Mouse_study_count.plot(kind="bar", color="r", alpha=0.5, align="center")
plt.xticks(rotation=30)
plt.title("Unique Mice Count per Regimen")
plt.ylabel("Unique Mice Count")
plt.show
plt.tight_layout()

# %%
Mouse_study_cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
plt.figure(figsize=(15,5))
drug_reg_counts = Mouse_study_cleaned_df["Drug Regimen"].value_counts()
plt.bar(drug_reg_counts.index.values, drug_reg_counts.values, color="r", alpha=0.5, align="center" )
plt.xticks(rotation=30)
plt.title("Unique Mice Count per Regimen")
plt.ylabel("Unique Mice Count")
plt.xlabel("Drug Regimen")
plt.show
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
Mouse_sex_df=pd.DataFrame(Mouse_study_cleaned_df["Sex"].value_counts())
labels=Mouse_sex_df["Sex"]
colors= ["orange", "green"]
Mouse_sex_df.plot(kind="pie", colors=colors, autopct="%1.1f%%", shadow=True, startangle=140, subplots=True)
plt.axis("equal")
plt.title("Sex Distrubution")
# Out:
# Text(0.5, 1.0, 'Sex Distrubution')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
Mouse_sex_df=pd.DataFrame(Mouse_study_cleaned_df["Sex"].value_counts())
labels=Mouse_sex_df["Sex"]
colors= ["orange", "green"]
plt.pie(x= np.array(Mouse_sex_df).ravel(), labels=Mouse_sex_df["Sex"].index.values,colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
plt.title("Sex Distrubution")
plt.legend(Mouse_sex_df["Sex"].index.values)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
Mouse_study_max_df = Mouse_study_cleaned_df.groupby("Mouse ID")["Timepoint"].max()
#Mouse_study_max_df=Mouse_study_max_df.reset_index()
#print(Mouse_study_max_df)
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
Merged_drop_max_df = pd.merge(Mouse_study_cleaned_df, Mouse_study_max_df, how="inner", on=["Mouse ID", "Timepoint"] )

# %%
Merged_drop_max_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 244     z314     Stelasyn  Female          21          28          5
# 245     z435     Propriva  Female          12          26         10
# 246     z581    Infubinol  Female          24          25         45
# 247     z795     Naftisol  Female          13          29         45
# 248     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
Regimen =["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
     
# Create empty list to fill with tumor vol data (for plotting)
Tumor = []
    
        
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for x in Regimen:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    Merged_drug_tumor_loc_df=Merged_drop_max_df.loc[ Merged_drop_max_df["Drug Regimen"]==x,"Tumor Volume (mm3)"]
    # add subset
    Tumor.append(Merged_drug_tumor_loc_df)
    quartiles = Merged_drug_tumor_loc_df.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    #print(quartiles)
    #print(lowerq)
    #print(upperq)
    #print(lower_bound)
    #print(upper_bound)
    print(f"{x} outliers could be below {lower_bound: .2f} mm3 or above {upper_bound: .2f} mm3")
    # Determine outliers using upper and lower bounds
# Out:
# Capomulin outliers could be below  20.70 mm3 or above  51.83 mm3
# Ramicane outliers could be below  17.91 mm3 or above  54.31 mm3
# Infubinol outliers could be below  36.83 mm3 or above  82.74 mm3
# Ceftamin outliers could be below  25.36 mm3 or above  87.67 mm3

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
blue_diamond = dict(markerfacecolor="b", marker="D") 
plt.subplot()
labels=list(Merged_drop_max_df["Drug Regimen"])
plt.title("Tumor Volume per Regimen")
plt.xlabel("Regimen")
plt.ylabel("Tumor Volume")
plt.boxplot(Tumor, labels = Regimen, flierprops=blue_diamond)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Mouse_ID = "x401"
Capomulin_regimen_df = Mouse_study_cleaned_df.loc[Mouse_study_cleaned_df["Drug Regimen"]== "Capomulin", :]
Mouse_treated_df = Capomulin_regimen_df.loc[Capomulin_regimen_df["Mouse ID"] == Mouse_ID, :]
x_axis = Mouse_treated_df["Timepoint"]
y_axis = Mouse_treated_df["Tumor Volume (mm3)"]
plt.plot(x_axis, y_axis)
plt.title("Tumor Volume vs. Time Point of x401")
plt.xlabel("Days")
plt.ylabel("Tumor Volume (mm3)")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
Tumor_avg_df=Capomulin_regimen_df.groupby(["Mouse ID"]).mean()
x_axis = Tumor_avg_df["Weight (g)"]
y_axis = Tumor_avg_df["Tumor Volume (mm3)"]
plt.scatter(x_axis, y_axis)
plt.title("Average Tumor Volume vs. Mouse Weight for the Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_axis = Tumor_avg_df["Weight (g)"]
y_axis = Tumor_avg_df["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Average Tumor Volume vs. Mouse Weight for the Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume")
print(f"The correlation coefficient between mouse weight and average tumor volume is {rvalue:.2f}") 
print(f"The linear regression: slope={slope:.2f}, intercept={intercept:.2f}, r-value={rvalue:.2f}, p-value={pvalue:.2f}, stderr={stderr:.2f}")
plt.show()
# Out:
# The correlation coefficient between mouse weight and average tumor volume is 0.84
# The linear regression: slope=0.95, intercept=21.55, r-value=0.84, p-value=0.00, stderr=0.13
